# %%
import rasterio
from rasterio import plot
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline
import os


#Seleccionar carpeta con los archivos
os.listdir('C:/Users/ricar/Downloads/back+/images/')
#Open images

b3 = rasterio.open('C:/Users/ricar/Downloads/back+/images/S-HARMONIZED_20210802T170849_20210802T171859_T15TVG_02Aug2021_B3.tif') #green
#b3 = image_data["B3"]

#VIS RED
b4 = rasterio.open('C:/Users/ricar/Downloads/back+/images/S-HARMONIZED_20210802T170849_20210802T171859_T15TVG_02Aug2021_B4.tif') #red
#b4 = image_data["B4"]

#NIR
b8 = rasterio.open('C:/Users/ricar/Downloads/back+/images/S-HARMONIZED_20210802T170849_20210802T171859_T15TVG_02Aug2021_B8.tif') #nir
#b8 = image_data["B8"]
#Valor de L
l=0
#View image size
b4.height
b4.width
b3.height
b3.width
#to know what kind of band it is 
b4.dtypes[0]
b3.dtypes[0]
#raster reference
b4.crs
b3.crs
#raster parameters
b4.transform
b3.transform
#raster transform parameters
b4.read(1)
b3.read(1)
#Change the arrays to float64 to accept division and decimals.
visr = b4.read(1).astype('float64')
visg = b3.read(1).astype('float64')
nir = b8.read(1).astype('float64')
nir
####################################################################################################################################
#Calculate the NDVI 
ndvi=np.where(
    #To eliminate the division by 0; when we know that the denominator is 0 we give the value of 0 automatically.
    (nir+visr)==0., 
    0, 
    #If this is not the case, we proceed to calculate the NDVI.
    (nir-visr)/(nir+visr)
    )
ndvi

#Calculate the SAVI 
#SAVI = ((NIR - Red) / (NIR + Red + L)) x (1 + L)
savi=np.where(
    #To eliminate the division by 0; when we know that the denominator is 0 we give the value of 0 automatically.
    (visr+nir + l)==0., 
    0, 
    #If this is not the case, we proceed to calculate the NDVI.
    ((nir-visr)/(visr+nir + l) ) * (1+l)
    )
savi


#Calculate the GCI 
gci=np.where(
    #To eliminate the division by 0; when we know that the denominator is 0 we give the value of 0 automatically.
    (visg)==0., 
    0, 
    #If this is not the case, we proceed to calculate the NDVI.
    (nir)/(visg) - 1
    )
gci
#################################################################################################################
#Now we take the generated image and display it with the NDVI values.
fig, ax = plt.subplots()
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
#We select the color map 'viridis'
im = ax.imshow(ndvi, cmap='viridis')
#Add colorbar
fig.colorbar(im, cax=cax, orientation='vertical')
plt.show()


#Now we take the generated image and display it with the NDVI values.
fig, ax = plt.subplots()
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
#We select the color map.mro
im = ax.imshow(savi, cmap='RdYlGn')
#Add colorbar
fig.colorbar(im, cax=cax, orientation='vertical')
plt.show()


#Now we take the generated image and display it with the NDVI values.
fig, ax = plt.subplots()
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
#We select the color map.mro
im = ax.imshow(gci, cmap='RdYlGn')
#Add colorbar
fig.colorbar(im, cax=cax, orientation='vertical')
plt.show()
